# %%
from qiskit.aqua.algorithms import VQE, NumPyEigensolver
import matplotlib.pyplot as plt
import numpy as np
from qiskit.chemistry.components.variational_forms import UCCSD
from qiskit.chemistry.components.initial_states import HartreeFock
from qiskit.circuit.library import EfficientSU2
from qiskit.aqua.components.optimizers import COBYLA, SPSA, SLSQP
from qiskit.aqua.operators import Z2Symmetries
from qiskit import IBMQ, BasicAer, Aer
from qiskit.chemistry.drivers import PySCFDriver, UnitsType
from qiskit.chemistry import FermionicOperator
from qiskit import IBMQ
from qiskit.aqua import QuantumInstance
from qiskit.ignis.mitigation.measurement import CompleteMeasFitter
from qiskit.providers.aer.noise import NoiseModel

import numpy as np
from numpy import pi
# importing Qiskit
from qiskit import QuantumCircuit, execute, Aer, IBMQ
from qiskit.providers.ibmq import least_busy
from qiskit.tools.monitor import job_monitor
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import plot_histogram, plot_bloch_vector
from math import sqrt, pi
# %config InlineBackend.figure_format = 'svg' # Makes the images look nice

from qiskit import IBMQ
IBMQ.save_account('78a4e395a27e3cce2d6bea6321d4b618bacc9db3c5f4506850b2616b7444da36b01e2c0d1f27119c77dbbde833366731ea64401e8fab2f852fa84a4c4317a11b', overwrite=True)

IBMQ.load_account()
provider = IBMQ.get_provider(hub='ibm-q')
nqubits = 4
backend = least_busy(provider.backends(filters=lambda x: x.configuration().n_qubits >= nqubits 
                                       and not x.configuration().simulator 
                                       and x.status().operational==True))
print("least busy backend: ", backend)
# Out:
# /home/sonobe/anaconda3/envs/quantum/lib/python3.8/site-packages/urllib3/connection.py:379: SystemTimeWarning: System time is way off (before 2019-01-01). This will probably lead to SSL verification errors
#   warnings.warn(
# /home/sonobe/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/providers/ibmq/ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '
# /home/sonobe/anaconda3/envs/quantum/lib/python3.8/site-packages/urllib3/connection.py:379: SystemTimeWarning: System time is way off (before 2019-01-01). This will probably lead to SSL verification errors
#   warnings.warn(
# /home/sonobe/anaconda3/envs/quantum/lib/python3.8/site-packages/urllib3/connection.py:379: SystemTimeWarning: System time is way off (before 2019-01-01). This will probably lead to SSL verification errors
#   warnings.warn(
# /home/sonobe/anaconda3/envs/quantum/lib/python3.8/site-packages/urllib3/connection.py:379: SystemTimeWarning: System time is way off (before 2019-01-01). This will probably lead to SSL verification errors
#   warnings.warn(
# /home/sonobe/anaconda3/envs/quantum/lib/python3.8/site-packages/urllib3/connection.py:379: SystemTimeWarning: System time is way off (before 2019-01-01). This will probably lead to SSL verification errors
#   warnings.warn(
# least busy backend:  ibmq_ourense

# %%
dist = 1.1
driver = PySCFDriver(atom='H .0 .0 -{}; H .0 .0 {}'.format(str(dist/2),str(dist/2)), unit=UnitsType.ANGSTROM, charge=0, spin=0, basis='sto3g')
molecule = driver.run()
repulsion_energy = molecule.nuclear_repulsion_energy
num_particles = molecule.num_alpha + molecule.num_beta
num_spin_orbitals = molecule.num_orbitals * 2
ferOp = FermionicOperator(h1=molecule.one_body_integrals, h2=molecule.two_body_integrals)
qubitOp = ferOp.mapping(map_type='parity')
qubitOp = Z2Symmetries.two_qubit_reduction(qubitOp, num_particles)
exact_solution = NumPyEigensolver(qubitOp).run()
exact_energies.append(np.real(exact_solution.eigenvalues) + repulsion_energy)
#print("Exact Result:", np.real(exact_solution.eigenvalues) + molecule.nuclear_repulsion_energy)
#print(num_spin_orbitals, num_particles)
initial_state = HartreeFock(
    num_spin_orbitals,
    num_particles,
    qubit_mapping='parity'
)
var_form = UCCSD(
    num_orbitals=num_spin_orbitals,
    num_particles=num_particles,
    initial_state=initial_state,
    qubit_mapping='parity'
)
print(var_form.compute_excitation_lists(num_orbitals=num_spin_orbitals, num_particles=num_particles))
# Out:
# ([[0, 1], [2, 3]], [[0, 1, 2, 3]])

# %%
from qiskit import Aer, execute
backend = BasicAer.get_backend("statevector_simulator")

distances = np.arange(0.5, 2.0, 0.1)
exact_energies = []
vqe_energies = []
optimizer = SLSQP(maxiter=5)
for dist in distances:
    driver = PySCFDriver(atom='H .0 .0 -{}; H .0 .0 {}'.format(str(dist/2),str(dist/2)), unit=UnitsType.ANGSTROM, charge=0, spin=0, basis='sto3g')
    molecule = driver.run()
    repulsion_energy = molecule.nuclear_repulsion_energy
    num_particles = molecule.num_alpha + molecule.num_beta
    num_spin_orbitals = molecule.num_orbitals * 2
    ferOp = FermionicOperator(h1=molecule.one_body_integrals, h2=molecule.two_body_integrals)
    qubitOp = ferOp.mapping(map_type='parity')
    qubitOp = Z2Symmetries.two_qubit_reduction(qubitOp, num_particles)
    exact_solution = NumPyEigensolver(qubitOp).run()
    exact_energies.append(np.real(exact_solution.eigenvalues) + repulsion_energy)
    #print("Exact Result:", np.real(exact_solution.eigenvalues) + molecule.nuclear_repulsion_energy)
    #print(num_spin_orbitals, num_particles)
    initial_state = HartreeFock(
        num_spin_orbitals,
        num_particles,
        qubit_mapping='parity'
    )
    var_form = UCCSD(
        num_orbitals=num_spin_orbitals,
        num_particles=num_particles,
        initial_state=initial_state,
        qubit_mapping='parity'
    )
    vqe = VQE(qubitOp, var_form, optimizer=optimizer)
    ret = vqe.run(backend)
    vqe_result = np.real(ret['eigenvalue']+ repulsion_energy)
    vqe_energies.append(vqe_result)
    print("Interatomic Distance:", np.round(dist, 2), "VQE Result:", vqe_result, "Exact Energy:", exact_energies[-1])
# Out:
# Interatomic Distance: 0.5 VQE Result: -1.055159794447963 Exact Energy: [-1.05515979]
# Interatomic Distance: 0.6 VQE Result: -1.1162860068311218 Exact Energy: [-1.11628601]
# Interatomic Distance: 0.7 VQE Result: -1.1361894540113098 Exact Energy: [-1.13618945]
# Interatomic Distance: 0.8 VQE Result: -1.1341476666206258 Exact Energy: [-1.13414767]
# Interatomic Distance: 0.9 VQE Result: -1.1205601297760266 Exact Energy: [-1.12056028]
# Interatomic Distance: 1.0 VQE Result: -1.101150318806139 Exact Energy: [-1.10115033]
# Interatomic Distance: 1.1 VQE Result: -1.0791929449548832 Exact Energy: [-1.07919294]
# Interatomic Distance: 1.2 VQE Result: -1.056740744929072 Exact Energy: [-1.05674075]
# Interatomic Distance: 1.3 VQE Result: -1.0351862637952831 Exact Energy: [-1.03518627]
# Interatomic Distance: 1.4 VQE Result: -1.0154682470624605 Exact Energy: [-1.01546825]
# Interatomic Distance: 1.5 VQE Result: -0.9981493525210149 Exact Energy: [-0.99814935]
# Interatomic Distance: 1.6 VQE Result: -0.9834727288648997 Exact Energy: [-0.98347273]
# Interatomic Distance: 1.7 VQE Result: -0.9714266884527487 Exact Energy: [-0.97142669]
# Interatomic Distance: 1.8 VQE Result: -0.9618166585233301 Exact Energy: [-0.96181695]
# Interatomic Distance: 1.9 VQE Result: -0.9543388539973547 Exact Energy: [-0.95433885]
# Process ForkProcess-44:
# Process ForkProcess-43:
# Process ForkProcess-41:
# Process ForkProcess-42:
# Process ForkProcess-47:
# Process ForkProcess-46:
# Process ForkProcess-45:
# Process ForkProcess-48:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/queues.py", line 97, in get
#     res = self._recv_bytes()
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()

# %%
plt.plot(distances, exact_energies, label="Exact Energy")
plt.plot(distances, vqe_energies, label="VQE Energy")
plt.xlabel('Atomic distance (Angstrom)')
plt.ylabel('Energy')
plt.title("SLSQP on simulater")
plt.legend()
plt.savefig("H2_statevector_spsqp.png")
plt.show()

# %%
from qiskit import Aer, execute
backend = BasicAer.get_backend("statevector_simulator")

distances = np.arange(0.5, 2.0, 0.1)
exact_energies = []
vqe_energies = []
optimizer = SPSA(maxiter=100)
for dist in distances:
    driver = PySCFDriver(atom='H .0 .0 -{}; H .0 .0 {}'.format(str(dist/2),str(dist/2)), unit=UnitsType.ANGSTROM, charge=0, spin=0, basis='sto3g')
    molecule = driver.run()
    repulsion_energy = molecule.nuclear_repulsion_energy
    num_particles = molecule.num_alpha + molecule.num_beta
    num_spin_orbitals = molecule.num_orbitals * 2
    ferOp = FermionicOperator(h1=molecule.one_body_integrals, h2=molecule.two_body_integrals)
    qubitOp = ferOp.mapping(map_type='parity')
    qubitOp = Z2Symmetries.two_qubit_reduction(qubitOp, num_particles)
    exact_solution = NumPyEigensolver(qubitOp).run()
    exact_energies.append(np.real(exact_solution.eigenvalues) + repulsion_energy)
    #print("Exact Result:", np.real(exact_solution.eigenvalues) + molecule.nuclear_repulsion_energy)
    #print(num_spin_orbitals, num_particles)
    initial_state = HartreeFock(
        num_spin_orbitals,
        num_particles,
        qubit_mapping='parity'
    )
    var_form = UCCSD(
        num_orbitals=num_spin_orbitals,
        num_particles=num_particles,
        initial_state=initial_state,
        qubit_mapping='parity'
    )
    vqe = VQE(qubitOp, var_form, optimizer=optimizer)
    ret = vqe.run(backend)
    vqe_result = np.real(ret['eigenvalue']+ repulsion_energy)
    vqe_energies.append(vqe_result)
    print("Interatomic Distance:", np.round(dist, 2), "VQE Result:", vqe_result, "Exact Energy:", exact_energies[-1])
# Out:
# Interatomic Distance: 0.5 VQE Result: -1.055113013142788 Exact Energy: [-1.05515979]
# Interatomic Distance: 0.6 VQE Result: -0.6794105305095144 Exact Energy: [-1.11628601]
# Interatomic Distance: 0.7 VQE Result: -0.5316818180772193 Exact Energy: [-1.13618945]
# Interatomic Distance: 0.8 VQE Result: -0.36866508388406893 Exact Energy: [-1.13414767]
# Interatomic Distance: 0.9 VQE Result: -0.3223613707069203 Exact Energy: [-1.12056028]
# Interatomic Distance: 1.0 VQE Result: -0.5554128249854005 Exact Energy: [-1.10115033]
# Interatomic Distance: 1.1 VQE Result: -0.5718733403043689 Exact Energy: [-1.07919294]
# Interatomic Distance: 1.2 VQE Result: -0.7843473069466937 Exact Energy: [-1.05674075]
# Interatomic Distance: 1.3 VQE Result: -0.8132580135568921 Exact Energy: [-1.03518627]
# Interatomic Distance: 1.4 VQE Result: -0.5273809897002573 Exact Energy: [-1.01546825]
# Interatomic Distance: 1.5 VQE Result: -0.8354731964620284 Exact Energy: [-0.99814935]
# Interatomic Distance: 1.6 VQE Result: -0.5469537715372794 Exact Energy: [-0.98347273]
# Interatomic Distance: 1.7 VQE Result: -0.5345164513939342 Exact Energy: [-0.97142669]
# Interatomic Distance: 1.8 VQE Result: -0.6697029305314892 Exact Energy: [-0.96181695]
# Interatomic Distance: 1.9 VQE Result: -0.8051707620423725 Exact Energy: [-0.95433885]

# %%
plt.plot(distances, exact_energies, label="Exact Energy")
plt.plot(distances, vqe_energies, label="VQE Energy")
plt.xlabel('Atomic distance (Angstrom)')
plt.ylabel('Energy')
plt.title("SPSA on simulater")
plt.legend()
plt.savefig("H2_statevector_spsqp.png")
plt.show()

# %%
from qiskit import Aer, execute
from qiskit.aqua.components.optimizers import ADAM
backend = BasicAer.get_backend("statevector_simulator")

distances = np.arange(0.5, 2.0, 0.1)
exact_energies = []
vqe_energies = []
optimizer = ADAM(maxiter=1000)
for dist in distances:
    driver = PySCFDriver(atom='H .0 .0 -{}; H .0 .0 {}'.format(str(dist/2),str(dist/2)), unit=UnitsType.ANGSTROM, charge=0, spin=0, basis='sto3g')
    molecule = driver.run()
    repulsion_energy = molecule.nuclear_repulsion_energy
    num_particles = molecule.num_alpha + molecule.num_beta
    num_spin_orbitals = molecule.num_orbitals * 2
    ferOp = FermionicOperator(h1=molecule.one_body_integrals, h2=molecule.two_body_integrals)
    qubitOp = ferOp.mapping(map_type='parity')
    qubitOp = Z2Symmetries.two_qubit_reduction(qubitOp, num_particles)
    exact_solution = NumPyEigensolver(qubitOp).run()
    exact_energies.append(np.real(exact_solution.eigenvalues) + repulsion_energy)
    #print("Exact Result:", np.real(exact_solution.eigenvalues) + molecule.nuclear_repulsion_energy)
    #print(num_spin_orbitals, num_particles)
    initial_state = HartreeFock(
        num_spin_orbitals,
        num_particles,
        qubit_mapping='parity'
    )
    var_form = UCCSD(
        num_orbitals=num_spin_orbitals,
        num_particles=num_particles,
        initial_state=initial_state,
        qubit_mapping='parity'
    )
    vqe = VQE(qubitOp, var_form, optimizer=optimizer)
    ret = vqe.run(backend)
    vqe_result = np.real(ret['eigenvalue']+ repulsion_energy)
    vqe_energies.append(vqe_result)
    print("Interatomic Distance:", np.round(dist, 2), "VQE Result:", vqe_result, "Exact Energy:", exact_energies[-1])
# Out:
# Interatomic Distance: 0.5 VQE Result: -1.0551597941670223 Exact Energy: [-1.05515979]
# Interatomic Distance: 0.6 VQE Result: -1.1162860055368335 Exact Energy: [-1.11628601]
# Interatomic Distance: 0.7 VQE Result: -1.136189452168126 Exact Energy: [-1.13618945]
# Interatomic Distance: 0.8 VQE Result: -1.1341476663719514 Exact Energy: [-1.13414767]
# Interatomic Distance: 0.9 VQE Result: -1.1205602781419701 Exact Energy: [-1.12056028]
# Interatomic Distance: 1.0 VQE Result: -1.1011503301438368 Exact Energy: [-1.10115033]
# Interatomic Distance: 1.1 VQE Result: -1.0791929446794155 Exact Energy: [-1.07919294]
# Interatomic Distance: 1.2 VQE Result: -1.056740744939618 Exact Energy: [-1.05674075]
# Interatomic Distance: 1.3 VQE Result: -1.0351862664226295 Exact Energy: [-1.03518627]
# Interatomic Distance: 1.4 VQE Result: -1.015468249279349 Exact Energy: [-1.01546825]
# Interatomic Distance: 1.5 VQE Result: -0.998149353459226 Exact Energy: [-0.99814935]
# Interatomic Distance: 1.6 VQE Result: -0.9834727290272756 Exact Energy: [-0.98347273]
# Interatomic Distance: 1.7 VQE Result: -0.971426688422601 Exact Energy: [-0.97142669]
# Interatomic Distance: 1.8 VQE Result: -0.9618042394518331 Exact Energy: [-0.96181695]
# Interatomic Distance: 1.9 VQE Result: -0.9539698488584392 Exact Energy: [-0.95433885]

# %%
provider = IBMQ.get_provider(hub='ibm-q')
backend = Aer.get_backend("qasm_simulator")
device = provider.get_backend("ibmq_ourense")
coupling_map = device.configuration().coupling_map
noise_model = NoiseModel.from_backend(device.properties())
quantum_instance = QuantumInstance(backend=backend, 
                                   shots=4096, 
                                   noise_model=noise_model,
                                   coupling_map=coupling_map,
                                   measurement_error_mitigation_cls=CompleteMeasFitter,
                                   cals_matrix_refresh_period=30)

distances = np.arange(0.5, 2.0, 0.1)
exact_energies = []
vqe_energies = []
optimizer = ADAM(maxiter=1000)
somes = []
for dist in distances:
    driver = PySCFDriver(atom='H .0 .0 -{}; H .0 .0 {}'.format(str(dist/2),str(dist/2)), unit=UnitsType.ANGSTROM, charge=0, spin=0, basis='sto3g')
    molecule = driver.run()
    repulsion_energy = molecule.nuclear_repulsion_energy
    num_particles = molecule.num_alpha + molecule.num_beta
    num_spin_orbitals = molecule.num_orbitals * 2
    ferOp = FermionicOperator(h1=molecule.one_body_integrals, h2=molecule.two_body_integrals)
    qubitOp = ferOp.mapping(map_type='parity')
    qubitOp = Z2Symmetries.two_qubit_reduction(qubitOp, num_particles)
    exact_solution = NumPyEigensolver(qubitOp).run()
    exact_energies.append(np.real(exact_solution.eigenvalues) + repulsion_energy)
    #print("Exact Result:", np.real(exact_solution.eigenvalues) + molecule.nuclear_repulsion_energy)
    #print(num_spin_orbitals, num_particles)
    initial_state = HartreeFock(
        num_spin_orbitals,
        num_particles,
        qubit_mapping='parity'
    )
    var_form = UCCSD(
        num_orbitals=num_spin_orbitals,
        num_particles=num_particles,
        initial_state=initial_state,
        qubit_mapping='parity'
    )
    vqe = VQE(qubitOp, var_form, optimizer=optimizer)
    ret = vqe.run(quantum_instance)
    #circuit = vqe.get_optimal_circuit()
    #outcome = vqe.get_optimal_vector()
    #prob_vector_for_params = vqe.get_prob_vector_for_params()
    #somes.append([circuit, outcome])
    print(ret.keys())
    vqe_result = np.real(ret['eigenvalue']+ repulsion_energy)
    vqe_energies.append(vqe_result)
    print("Interatomic Distance:", np.round(dist, 2), "VQE Result:", vqe_result, "Exact Energy:", exact_energies[-1])
# Out:
# Process ForkProcess-33892:
# Process ForkProcess-33890:
# Traceback (most recent call last):
# Process ForkProcess-33891:
# Process ForkProcess-33889:
# Traceback (most recent call last):
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/process.py", line 233, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/queues.py", line 96, in get
#     with self._rlock:
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/queues.py", line 97, in get
#     res = self._recv_bytes()
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/home/sonobe/anaconda3/envs/quantum/lib/python3.8/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/tools/parallel.py in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     122                 param = map(lambda value: (task, value, task_args, task_kwargs), values)
# --> 123                 future = executor.map(_task_wrapper, param)
#     124
#
# ~/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/process.py in map(self, fn, timeout, chunksize, *iterables)
#     673
# --> 674         results = super().map(partial(_process_chunk, fn),
#     675                               _get_chunks(*iterables, chunksize=chunksize),
#
# ~/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/_base.py in map(self, fn, timeout, chunksize, *iterables)
#     599
# --> 600         fs = [self.submit(fn, *args) for args in zip(*iterables)]
#     601
#
# ~/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/_base.py in <listcomp>(.0)
#     599
# --> 600         fs = [self.submit(fn, *args) for args in zip(*iterables)]
#     601
#
# ~/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/process.py in submit(*args, **kwargs)
#     644
# --> 645             self._start_queue_management_thread()
#     646             return f
#
# ~/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/process.py in _start_queue_management_thread(self)
#     583             # Start the processes so that their sentinels are known.
# --> 584             self._adjust_process_count()
#     585             self._queue_management_thread = threading.Thread(
#
# ~/anaconda3/envs/quantum/lib/python3.8/concurrent/futures/process.py in _adjust_process_count(self)
#     607                       self._initargs))
# --> 608             p.start()
#     609             self._processes[p.pid] = p
#
# ~/anaconda3/envs/quantum/lib/python3.8/multiprocessing/process.py in start(self)
#     120         _cleanup()
# --> 121         self._popen = self._Popen(self)
#     122         self._sentinel = self._popen.sentinel
#
# ~/anaconda3/envs/quantum/lib/python3.8/multiprocessing/context.py in _Popen(process_obj)
#     276             from .popen_fork import Popen
# --> 277             return Popen(process_obj)
#     278
#
# ~/anaconda3/envs/quantum/lib/python3.8/multiprocessing/popen_fork.py in __init__(self, process_obj)
#      15     def __init__(self, process_obj):
# ---> 16         util._flush_std_streams()
#      17         self.returncode = None
#
# ~/anaconda3/envs/quantum/lib/python3.8/multiprocessing/util.py in _flush_std_streams()
#     434     try:
# --> 435         sys.stdout.flush()
#     436     except (AttributeError, ValueError):
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/ipykernel/iostream.py in flush(self)
#     343             # request flush on the background thread
# --> 344             self.pub_thread.schedule(self._flush)
#     345             # wait for flush to actually get through, if we can.
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/ipykernel/iostream.py in schedule(self, f)
#     202         if self.thread.is_alive():
# --> 203             self._events.append(f)
#     204             # wake event thread (message content is ignored)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# QiskitError                               Traceback (most recent call last)
# <ipython-input-10-82f4171f5e4c> in <module>
#      41     )
#      42     vqe = VQE(qubitOp, var_form, optimizer=optimizer)
# ---> 43     ret = vqe.run(quantum_instance)
#      44     #circuit = vqe.get_optimal_circuit()
#      45     #outcome = vqe.get_optimal_vector()
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/aqua/algorithms/quantum_algorithm.py in run(self, quantum_instance, **kwargs)
#      69                 self.quantum_instance = quantum_instance
#      70
# ---> 71         return self._run()
#      72
#      73     @abstractmethod
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/aqua/algorithms/minimum_eigen_solvers/vqe.py in _run(self)
#     427                     bind_params=self._var_form_params,
#     428                     backend=self._quantum_instance)
# --> 429         vqresult = self.find_minimum(initial_point=self.initial_point,
#     430                                      var_form=self.var_form,
#     431                                      cost_fn=self._energy_evaluation,
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/aqua/algorithms/vq_algorithm.py in find_minimum(self, initial_point, var_form, cost_fn, optimizer, gradient_fn)
#     207
#     208         logger.info('Starting optimizer.\nbounds=%s\ninitial point=%s', bounds, initial_point)
# --> 209         opt_params, opt_val, num_optimizer_evals = optimizer.optimize(nparms,
#     210                                                                       cost_fn,
#     211                                                                       variable_bounds=bounds,
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/aqua/components/optimizers/adam_amsgrad.py in optimize(self, num_vars, objective_function, gradient_function, variable_bounds, initial_point)
#     241                                                         (objective_function, self._eps))
#     242
# --> 243         point, value, nfev = self.minimize(objective_function, initial_point, gradient_function)
#     244         return point, value, nfev
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/aqua/components/optimizers/adam_amsgrad.py in minimize(self, objective_function, initial_point, gradient_function)
#     190         while self._t < self._maxiter:
#     191             if self._t > 0:
# --> 192                 derivative = gradient_function(params)
#     193             self._t += 1
#     194             self._m = self._beta_1 * self._m + (1 - self._beta_1) * derivative
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/aqua/components/optimizers/optimizer.py in function_wrapper(*wrapper_args)
#     130         """
#     131         def function_wrapper(*wrapper_args):
# --> 132             return function(*(wrapper_args + args))
#     133         return function_wrapper
#     134
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/aqua/components/optimizers/optimizer.py in gradient_num_diff(x_center, f, epsilon, max_evals_grouped)
#     109         for chunk in chunks:  # eval the chunks in order
#     110             parallel_parameters = np.concatenate(chunk)
# --> 111             todos_results = f(parallel_parameters)  # eval the points in a chunk (order preserved)
#     112             if isinstance(todos_results, float):
#     113                 grad.append((todos_results - forig) / epsilon)
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/aqua/algorithms/minimum_eigen_solvers/vqe.py in _energy_evaluation(self, parameters)
#     523
#     524         start_time = time()
# --> 525         sampled_expect_op = self._circuit_sampler.convert(self._expect_op, params=param_bindings)
#     526         means = np.real(sampled_expect_op.eval())
#     527
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/aqua/operators/converters/circuit_sampler.py in convert(self, operator, params)
#     203         circs = list(self._circuit_ops_cache.values()) if not self._transpiled_circ_cache else None
#     204         p_b = cast(List[Dict[Parameter, List[float]]], param_bindings)
# --> 205         sampled_statefn_dicts = self.sample_circuits(circuit_sfns=circs,
#     206                                                      param_bindings=p_b)
#     207
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/aqua/operators/converters/circuit_sampler.py in sample_circuits(self, circuit_sfns, param_bindings)
#     290             ready_circs = self._transpiled_circ_cache
#     291
# --> 292         results = self.quantum_instance.execute(ready_circs,
#     293                                                 had_transpiled=self._transpile_before_bind)
#     294
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/aqua/quantum_instance.py in execute(self, circuits, had_transpiled)
#     299
#     300         # assemble
# --> 301         qobj = self.assemble(circuits)
#     302
#     303         if self._meas_error_mitigation_cls is not None:
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/aqua/quantum_instance.py in assemble(self, circuits)
#     271                  circuits: Union[QuantumCircuit, List[QuantumCircuit]]) -> Qobj:
#     272         """ assemble circuits """
# --> 273         return compiler.assemble(circuits, **self._run_config.to_dict())
#     274
#     275     def execute(self,
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/compiler/assemble.py in assemble(experiments, backend, qobj_id, qobj_header, shots, memory, max_credits, seed_simulator, qubit_lo_freq, meas_lo_freq, qubit_lo_range, meas_lo_range, schedule_los, meas_level, meas_return, meas_map, memory_slot_size, rep_time, rep_delay, parameter_binds, parametric_pulses, init_qubits, **run_config)
#     151         end_time = time()
#     152         _log_assembly_time(start_time, end_time)
# --> 153         return assemble_circuits(circuits=bound_experiments, qobj_id=qobj_id,
#     154                                  qobj_header=qobj_header, run_config=run_config)
#     155
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/assembler/assemble_circuits.py in assemble_circuits(circuits, run_config, qobj_id, qobj_header)
#     267     qobj_config.n_qubits = max(qubit_sizes)
#     268
# --> 269     experiments_and_pulse_libs = parallel_map(_assemble_circuit, circuits, [run_config])
#     270     experiments = []
#     271     pulse_library = {}
#
# ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit/tools/parallel.py in parallel_map(task, values, task_args, task_kwargs, num_processes)
#     130                 Publisher().publish("terra.parallel.finish")
#     131                 os.environ['QISKIT_IN_PARALLEL'] = 'FALSE'
# --> 132                 raise QiskitError('Keyboard interrupt in parallel_map.')
#     133             # Otherwise just reset parallel flag and error
#     134             os.environ['QISKIT_IN_PARALLEL'] = 'FALSE'
#
# QiskitError: 'Keyboard interrupt in parallel_map.'
